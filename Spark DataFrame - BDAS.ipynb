# %% [markdown]
# # Spark DataFrame

# %%
# Step 2
import pandas as pd

file = r"Datasets/dataset.xlsx"

df = pd.read_excel(file, 'dataset')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %%
df_desc = df.describe().T
df_desc
# Out:
#                                                  count       mean        std  \
# Marital status                                  4424.0   1.178571   0.605747
# Application mode                                4424.0   6.886980   5.298964
# Application order                               4424.0   1.727848   1.313793
# Course                                          4424.0   9.899186   4.331792
# Daytime/evening attendance                      4424.0   0.890823   0.311897
# Previous qualification                          4424.0   2.531420   3.963707
# Nacionality                                     4424.0   1.254521   1.748447
# Mother's qualification                          4424.0  12.322107   9.026251
# Father's qualification                          4424.0  16.455244  11.044800
# Mother's occupation                             4424.0   7.317812   3.997828
# Father's occupation                             4424.0   7.819168   4.856692
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(df['Target'])


ds = sns.countplot(df, x='Curricular units 2nd sem (grade)')
sns.displot(df, x="Curricular units 2nd sem (grade)")


sns.displot(df, x="Curricular units 2nd sem (grade)", hue="Gender")


sns.relplot(data=df, x="Curricular units 2nd sem (grade)", y="Age at enrollment")

sns.displot(df, x="Target", hue="Scholarship holder")

import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#       2 import matplotlib.pyplot as plt
#       4 sns.countplot(df['Target'])
# ...

# %% [markdown]
# ## Data Exploration

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                              1                       1            1
# ...

# %%
# We can use the describe method get some general statistics on our data too. Remember to show the DataFrame!
# But what about data type?
df = pd.read_csv(r"Datasets/dataset.csv")
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nacionality  \
# count                 4424.000000             4424.000000  4424.000000
# mean                     0.890823                2.531420     1.254521
# std                      0.311897                3.963707     1.748447
# ...

# %%
df.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced', '1', '8',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
# ...

# %%
df = pd.read_excel(r"Datasets/dataset_to_be_clean.xlsx",'dataset')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  288 non-null    int64
#  1   Application mode                                288 non-null    int64
#  2   Application order                               288 non-null    int64
#  3   Course                                          271 non-null    float64
#  4   Daytime/evening attendance                      288 non-null    int64
#  5   Previous qualification                          288 non-null    int64
#  6   Nacionality                                     86 non-null     float64
#  7   Mother's qualification                          288 non-null    int64
#  8   Father's qualification                          288 non-null    int64
# ...

# %%
df = df.fillna(999)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 34 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  288 non-null    int64
#  1   Application mode                                288 non-null    int64
#  2   Application order                               288 non-null    int64
#  3   Course                                          288 non-null    float64
#  4   Daytime/evening attendance                      288 non-null    int64
#  5   Previous qualification                          288 non-null    int64
#  6   Mother's qualification                          288 non-null    int64
#  7   Father's qualification                          288 non-null    int64
#  8   Mother's occupation                             288 non-null    int64
# ...

# %%
df = df.drop("Nacionality", axis='columns')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 34 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  288 non-null    int64
#  1   Application mode                                288 non-null    int64
#  2   Application order                               288 non-null    int64
#  3   Course                                          288 non-null    float64
#  4   Daytime/evening attendance                      288 non-null    int64
#  5   Previous qualification                          288 non-null    int64
#  6   Mother's qualification                          288 non-null    int64
#  7   Father's qualification                          288 non-null    int64
#  8   Mother's occupation                             288 non-null    int64
# ...

# %%
df = df[(df["Curricular units 1st sem (enrolled)"] > 0)
   |
   (df["Curricular units 2nd sem (enrolled)"] > 0)]
uselesscolumns = [
    "Application mode",
    "Application order",
    "Tuition fees up to date",
    "Curricular units 1st sem (credited)",
    "Curricular units 1st sem (enrolled)",
    "Curricular units 1st sem (evaluations)",
    "Curricular units 1st sem (approved)",
    "Curricular units 2nd sem (credited)",
    "Curricular units 2nd sem (enrolled)",
    "Curricular units 2nd sem (evaluations)",
    "Curricular units 2nd sem (approved)",
    ]
for x in uselesscolumns:
    df = df.drop(x, axis='columns')
df["Total Grade"] = df["Curricular units 1st sem (grade)"] + df["Curricular units 2nd sem (grade)"]
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4244 entries, 1 to 4423
# Data columns (total 25 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4244 non-null   int64
#  1   Course                                          4244 non-null   int64
#  2   Daytime/evening attendance                      4244 non-null   int64
#  3   Previous qualification                          4244 non-null   int64
#  4   Nacionality                                     4244 non-null   int64
#  5   Mother's qualification                          4244 non-null   int64
#  6   Father's qualification                          4244 non-null   int64
#  7   Mother's occupation                             4244 non-null   int64
#  8   Father's occupation                             4244 non-null   int64
# ...

# %%
df = df[df["Target"] != "Enrolled"]
g = df.groupby('Target')
bdf = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))
sns.countplot(bdf['Target'])
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Target', ylabel='count'>

# %%
# Out:
#       Marital status  Course  Daytime/evening attendance  \
# 1                  1      11                           1
# 2                  1       5                           1
# 3                  1      15                           1
# 4                  2       3                           0
# 5                  2      17                           0
# ...              ...     ...                         ...
# 4419               1      15                           1
# 4420               1      15                           1
# 4421               1      12                           1
# 4422               1       9                           1
# 4423               1      15                           1
#
#       Previous qualification  Nacionality  Mother's qualification  \
# 1                          1            1                       1
# 2                          1            1                      22
# 3                          1            1                      23
# ...

# %%
file1 = r"Datasets/dataset_to_be_merge_1.xlsx"
file2 = r"Datasets/dataset_to_be_merge_2.xlsx"
df1 = pd.read_excel(file1, 'Sheet1')
df2 = pd.read_excel(file2, 'Sheet1')
print(df1.shape)
print(df2.shape)
dfm = pd.concat([df1, df2])
dfm.shape
# Out:
# (12, 35)
# (26, 35)
# (38, 35)

# %%
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Target', ylabel='count'>

# %%
corr = df.corr()
corr
# Out:
#                                                 Marital status    Course  \
# Marital status                                        1.000000 -0.001894
# Course                                               -0.001894  1.000000
# Daytime/evening attendance                           -0.272338 -0.046684
# Previous qualification                                0.118369 -0.190525
# Nacionality                                          -0.020023  0.004372
# Mother's qualification                                0.186047  0.045168
# Father's qualification                                0.128743  0.035627
# Mother's occupation                                   0.068678  0.021280
# Father's occupation                                   0.023040  0.008901
# Displaced                                            -0.233641  0.050708
# Educational special needs                            -0.027778  0.011230
# Debtor                                                0.036168 -0.054897
# ...
